# %% [markdown]
# # Applying Temporal Convonotional Networks to the Virtual Flow Metering Problem (Testing Robustness)
#
# ## Author: Ridha Alkhabaz
#
# ### Imports:

# %%
### to hide warning messages:
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
### to build the TCN model 
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, RepeatVector
from tensorflow.keras.preprocessing import sequence
from tcn import TCN, compiled_tcn
import tensorflow as tf
import os
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/ElectricDemandForecasting-DL/src/")
from models import tcn
# for data configurations
import sys
import zipfile
from dateutil.parser import parse
import json
from random import shuffle
import random
import datetime
import math
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot, dates
from datetime import timedelta
from pandas import read_csv
from pandas import datetime
from numpy import array
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import datetime as dttm

# %%
os.chdir('/Users/ridhaalkhabaz/Documents/GitHub/VFM_ML/src')
from preprocessing import read_data_slugging, read_data_well
from configuration import configure 
os.chdir('/Users/ridhaalkhabaz/Documents/GitHub/VFM_ML')

# %%
fp, headers, scaler = read_data_well('welltest.csv', plot_data=True)

# %% [markdown]
# ### Data configuration and Reading:
#
# #### First: Riser data:
#
# ##### Reading the data and formating:

# %%
# Convert the sequence of seconds into datetime array
def parser(x):
    now_seconds = 0
    y = x.astype(np.float) + now_seconds
    z = pd.to_datetime(y, unit='s')
    return z
# the following are functions to observe the robustness of our model 
def spikes_addition(data, num_points=0, is_well=False):
    # some outliers and spikes
    for i in random.sample(range(0, len(data)), num_points):
        data[i][1] = np.random.uniform(data[:,1].min(),data[:,1].max())
        data[i][2] = np.random.uniform(data[:,2].min(),data[:,2].max())
        data[i][3] = np.random.uniform(data[:,3].min(),data[:,3].max())
        data[i][4] = np.random.uniform(data[:,4].min(),data[:,4].max())
        data[i][5] = np.random.uniform(data[:,5].min(),data[:,5].max())
        if is_well:
            continue
        data[i][6] = np.random.uniform(data[:,6].min(),data[:,6].max())
        data[i][7] = np.random.uniform(data[:,7].min(),data[:,7].max())
        data[i][8] = np.random.uniform(data[:,8].min(),data[:,8].max())
        data[i][9] = np.random.uniform(data[:,9].min(),data[:,9].max())
    return data
def gaussian_noise_addition(data, mu=0, sigma=0.005):
    ## adding noise after normalization 
    noise = np.random.normal(mu, sigma, data[:, 1:].shape)
    data[:, 1:] = data[:, 1:] + noise
    return data
def random_missing_data(data, num_points=0, is_well=False):
    from random import randint
    index = [randint(0, len(data)) for i in range(num_points)]
    data[index, 1:len(data[0])] = 0
#     if is_well:
#         data[index, 1:6] = 0
#     else:
#         data[index, 1:10] = 0
    return data, index

# %%
# Read the data from fname and eventually plot them
def read_data(fname, params=[0, 0, 5e-3, 10]):
    # Read the time serie
    datats = read_csv(fname, header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

    headers = list(datats.columns.values)
    headers.insert(0, datats.index.name)

    # Resample the data using a uniform timestep
    datats = datats.resample('S').mean()
    datats = datats.interpolate(method='linear')
    # Convert data to numpy array
    data = datats.reset_index().values
    # Adding spikes:
    data = spikes_addition(data, num_points=int(params[0]))
    # Replace timestamps with seconds
    time_sec = array([data[i, 0].timestamp() for i in range(len(data))])
    data = np.c_[time_sec, data[:, 1:]]

    # Normalize the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaler = scaler.fit(data)
    scaler.scale_[0] = 1    # Do not normalize time

    # Apply the same normalization to all pressure readings
    pind = list(range(1, 8))  # Indices of pressure readings
    pmin = scaler.data_min_[pind].min()
    pmax = scaler.data_max_[pind].max()
    scaler.scale_[pind] = ((scaler.feature_range[1] - scaler.feature_range[0]) / (pmax - pmin))
    scaler.min_[pind] = scaler.feature_range[0] - pmin * scaler.scale_[pind]

    data = scaler.transform(data)
    # Adding gaussian noise
    data = gaussian_noise_addition(data, mu=params[1], sigma=params[2])
    
    # Removing some points:
    data, _ = random_missing_data(data, num_points=int(params[3]))

    return data, scaler

# %%
import os
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM/src")
import preprocessing 
from preprocessing import read_data_slugging
import pandas as pd

# %%
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM")
data, _ = read_data_slugging('riser_pq_uni.csv', params=[0, 0, 5e-3, 100], is_not_clean=True)
dfx = pd.DataFrame.from_dict(dict(zip(['ds', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7','gas(m3/day)', 'liquid(m3/day)' ], data.T)))

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
ax.set_title('the data set visualization for better understanding')
ax.plot(dfx['ds'], dfx['gas(m3/day)'], marker=".", label='gas')
ax.plot(dfx['ds'], dfx['liquid(m3/day)'], marker=".", label='liquid')
ax.legend()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ##### Sliding window technique (Data configuration):

# %%
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM")
data_riser, _= read_data('riser_pq_uni.csv', params=np.array([0, 0, 5e-3, 100]))
df_riser = pd.DataFrame.from_dict(dict(zip(['ds', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7','gas(m3/day)', 'liquid(m3/day)' ], data_riser.T)))
### previous readings for univariate model 
dt_gas_riser = np.array(df_riser['gas(m3/day)'])
dt_liquid_riser = np.array(df_riser['liquid(m3/day)'])
### gas and liquid dataframe
df_gas_riser = df_riser.drop('liquid(m3/day)', axis=1)
df_gas_riser = df_gas_riser.set_index('ds')
df_liquid_riser = df_riser.drop('gas(m3/day)', axis=1)
df_liquid_riser = df_liquid_riser.set_index('ds')

# %% [markdown]
# ###### Some visualization for the data:

# %%
df_riser = df_riser.reset_index()
fig,ax = plt.subplots()
ax.set_title('the data set visualization for better understanding')
ax.plot(df_riser['ds'], df_riser['gas(m3/day)'], marker=".", label='gas')
ax.plot(df_riser['ds'], df_riser['liquid(m3/day)'], marker=".", label='liquid')
ax.legend()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
df_riser = df_riser.set_index('ds')

# %% [markdown]
# ##### Model Construction and Hyperparameters:

# %%
# Model Hyperparemeters (general hyperparameters)
FORECAST_HORIZON = 5 #secs 
PAST_HISTORY = 300
BATCH_SIZE = 64
EPOCHS = 100

# %% [markdown]
# #### GAS (models)
# ##### Univariate Model:

# %%
INPUT_DIMSION = 1
model_gas_uni = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_gas_uni.summary()
model_gas_uni.compile('adam', 'mse')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn (TCN)                    (None, 64)                136256
# _________________________________________________________________
# dense (Dense)                (None, 5)                 325
# =================================================================
# Total params: 136,581
# Trainable params: 136,581
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Multivariate Model:

# %%
INPUT_DIMSION = 8 # we include pressure readings and past observations of gas flow rate 
model_gas_mult = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON)  # output.shape = (batch, output_timesteps, 64)
    ]
)

model_gas_mult.summary()
model_gas_mult.compile('adam', 'mse')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_1 (TCN)                  (None, 64)                138048
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 138,373
# Trainable params: 138,373
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Liquid Models:
# ##### Univariate Model:

# %%
INPUT_DIMSION = 1
model_liq_uni = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON)  # output.shape = (batch, output_timesteps, 64)
    ]
)

model_liq_uni.summary()
model_liq_uni.compile('adam', 'mse')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_2 (TCN)                  (None, 64)                136256
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 136,581
# Trainable params: 136,581
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Multivariate Model:

# %%
INPUT_DIMSION = 8
model_liquid_mult = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON)  # output.shape = (batch, output_timesteps, 64)
    ]
)

model_liquid_mult.summary()
model_liquid_mult.compile('adam', 'mse')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_3 (TCN)                  (None, 64)                138048
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 138,373
# Trainable params: 138,373
# Non-trainable params: 0
# _________________________________________________________________

# %%
def univariate_data(tseries, start_index, end_index, history_size, forecast_horizon, step=5, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size

    for i in range(start_index, end_index - forecast_horizon + 1):
        indices = range(i - history_size, i, step)
        # Reshape data from (history_size,) to (history_size, 1)
        data.append(np.reshape(tseries[indices], (history_size, 1)))

        if single_step:
            labels.append(tseries[i + forecast_horizon])
        else:
            labels.append(tseries[i:i + forecast_horizon])

    return np.array(data), np.array(labels)
def multivariate_data(tseries, start_index, end_index, history_size, forecast_horizon):
    data = []
    labels = []
    for i in range(start_index, end_index -history_size +1, forecast_horizon):
        end = i+history_size
        data.append(tseries[i:end, :])
        labels.append(tseries[end:end+forecast_horizon, 7:])
    return np.array(data), np.array(labels)

# %%
params = [0, 1500, 2500, 3000]
x_uni, y_uni = univariate_data(np.array(dt_gas_riser), params[0], params[1], PAST_HISTORY, FORECAST_HORIZON, step=1)

# %%
def configure(data, params = [0, 1500, 2500, 3000], multi = False):
    if multi:
        x_mult, y_mult= multivariate_data(np.array(data), params[0], params[1], PAST_HISTORY, FORECAST_HORIZON)
        valX_mult , valY_mult = multivariate_data(np.array(data), params[1], params[2], PAST_HISTORY, FORECAST_HORIZON)
        testX_mult, testY_mult = multivariate_data(np.array(data), params[2], params[3]-1, PAST_HISTORY, FORECAST_HORIZON)
        # to avoid combatibility issues
        x_mult = x_mult.astype(np.float32)
        y_mult = y_mult.astype(np.float32)
        valX_mult = valX_mult.astype(np.float32)
        valY_mult = valY_mult.astype(np.float32)
        testX_mult = testX_mult.astype(np.float32)
        testY_mult = testY_mult.astype(np.float32)
        # to build data set
        train_data_mult = tf.data.Dataset.from_tensor_slices((x_mult, y_mult)).cache().batch(BATCH_SIZE).repeat()
        val_data_mult = tf.data.Dataset.from_tensor_slices((valX_mult, valY_mult)).batch(BATCH_SIZE).repeat()
        return train_data_mult, val_data_mult, testX_mult, testY_mult
    # for univariate 
    x_uni, y_uni = univariate_data(np.array(data), params[0], params[1], PAST_HISTORY, FORECAST_HORIZON, single_step=False)
    valX_uni , valY_uni = univariate_data(np.array(data), params[1], params[2], PAST_HISTORY, FORECAST_HORIZON, step=1, single_step=False)
    testX_uni, testY_uni = univariate_data(np.array(data),params[2], params[3], PAST_HISTORY, FORECAST_HORIZON, step=1, single_step=False)
    # to avoid combatibality issues
    x_uni = x_uni.astype(np.float32)
    y_uni = y_uni.astype(np.float32)
    valX_uni = valX_uni.astype(np.float32)
    valY_uni = valY_uni.astype(np.float32)
    testX_uni = testX_uni.astype(np.float32)
    testY_uni = testY_uni.astype(np.float32)
    # to build data set 
    train_data_uni = tf.data.Dataset.from_tensor_slices((x_uni, y_uni)).cache().batch(BATCH_SIZE).repeat()
    val_data_uni = tf.data.Dataset.from_tensor_slices((valX_uni, valY_uni)).batch(BATCH_SIZE).repeat()
    return train_data_uni, val_data_uni, testX_uni, testY_uni

# %%
# gas (uni)
gas_uni_train, gas_uni_val , gas_uni_testX, gas_uni_testY = configure(dt_gas_riser,params = [0, 1500, 2500, 3000], multi = False)
gas_mult_train, gas_mult_val , gas_mult_testX, gas_mult_testY = configure(df_gas_riser,params = [0, 1500, 2500, 3000], multi = True)
# liquid (uni)
liq_uni_train, liq_uni_val, liq_uni_testX, liq_uni_testY = configure(dt_liquid_riser,params = [0, 1500, 2500, 3000], multi = False)
liq_mult_train, liq_mult_val, liq_mult_testX, liq_mult_testY = configure(df_liquid_riser,params = [0, 1500, 2500, 3000], multi = True)

# %%
##gas 
### univariate
evaluation_interval = 10
history_gas_uni = model_gas_uni.fit(gas_uni_train, epochs=50, steps_per_epoch=evaluation_interval, validation_data=gas_uni_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 15s 1s/step - loss: 4.6488 - val_loss: 0.4207
# Epoch 2/50
# 10/10 [==============================] - 7s 712ms/step - loss: 0.3395 - val_loss: 0.1493
# Epoch 3/50
# 10/10 [==============================] - 7s 717ms/step - loss: 0.1156 - val_loss: 0.0597
# Epoch 4/50
# 10/10 [==============================] - 6s 635ms/step - loss: 0.0439 - val_loss: 0.0367
# Epoch 5/50
# 10/10 [==============================] - 6s 614ms/step - loss: 0.0417 - val_loss: 0.0236
# Epoch 6/50
# 10/10 [==============================] - 6s 594ms/step - loss: 0.0144 - val_loss: 0.0193
# Epoch 7/50
# 10/10 [==============================] - 6s 578ms/step - loss: 0.0192 - val_loss: 0.0160
# Epoch 8/50
# 10/10 [==============================] - 6s 592ms/step - loss: 0.0086 - val_loss: 0.0140
# Epoch 9/50
# 10/10 [==============================] - 7s 718ms/step - loss: 0.0145 - val_loss: 0.0129
# Epoch 10/50
# 10/10 [==============================] - 7s 689ms/step - loss: 0.0081 - val_loss: 0.0115
# Epoch 11/50
# 10/10 [==============================] - 7s 723ms/step - loss: 0.0134 - val_loss: 0.0106
# Epoch 42/50
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0018 - val_loss: 0.0049
# Epoch 43/50
# 10/10 [==============================] - 7s 742ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 44/50
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 45/50
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 46/50
# 10/10 [==============================] - 5s 561ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 47/50
# 10/10 [==============================] - 6s 592ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 48/50
# 10/10 [==============================] - 5s 557ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 49/50
# 10/10 [==============================] - 7s 740ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 50/50
# 10/10 [==============================] - 7s 695ms/step - loss: 0.0017 - val_loss: 0.0041

# %%
### multivariate 
evaluation_interval = 10
history_gas_mult = model_gas_mult.fit(gas_mult_train, epochs=50, steps_per_epoch=evaluation_interval,\
                                    validation_data=gas_mult_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 6s 609ms/step - loss: 2.9726 - val_loss: 0.6158
# Epoch 2/50
# 10/10 [==============================] - 6s 642ms/step - loss: 0.3138 - val_loss: 0.1699
# Epoch 3/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.1186 - val_loss: 0.0753
# Epoch 4/50
# 10/10 [==============================] - 7s 718ms/step - loss: 0.0697 - val_loss: 0.0628
# Epoch 5/50
# 10/10 [==============================] - 7s 723ms/step - loss: 0.0544 - val_loss: 0.0384
# Epoch 6/50
# 10/10 [==============================] - 6s 648ms/step - loss: 0.0358 - val_loss: 0.0294
# Epoch 7/50
# 10/10 [==============================] - 7s 715ms/step - loss: 0.0328 - val_loss: 0.0264
# Epoch 8/50
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0230 - val_loss: 0.0211
# Epoch 9/50
# 10/10 [==============================] - 7s 695ms/step - loss: 0.0225 - val_loss: 0.0191
# Epoch 10/50
# 10/10 [==============================] - 6s 656ms/step - loss: 0.0177 - val_loss: 0.0181
# Epoch 11/50
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 12/50
# 10/10 [==============================] - 8s 795ms/step - loss: 0.0162 - val_loss: 0.0213
# Epoch 13/50
# 10/10 [==============================] - 7s 714ms/step - loss: 0.0188 - val_loss: 0.0258
# Epoch 14/50
# 10/10 [==============================] - 6s 607ms/step - loss: 0.0171 - val_loss: 0.0240
# Epoch 15/50
# 10/10 [==============================] - 6s 579ms/step - loss: 0.0173 - val_loss: 0.0182
# Epoch 16/50
# 10/10 [==============================] - 5s 532ms/step - loss: 0.0127 - val_loss: 0.0131
# Epoch 17/50
# 10/10 [==============================] - 5s 555ms/step - loss: 0.0126 - val_loss: 0.0163
# Epoch 18/50
# 10/10 [==============================] - 7s 688ms/step - loss: 0.0115 - val_loss: 0.0182
# Epoch 19/50
# 10/10 [==============================] - 6s 646ms/step - loss: 0.0125 - val_loss: 0.0124
# Epoch 20/50
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0098 - val_loss: 0.0135
# Epoch 21/50
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0118 - val_loss: 0.0198
# Epoch 22/50
# 10/10 [==============================] - 7s 686ms/step - loss: 0.0113 - val_loss: 0.0175
# Epoch 23/50
# 10/10 [==============================] - 7s 689ms/step - loss: 0.0117 - val_loss: 0.0175
# Epoch 24/50
# 10/10 [==============================] - 6s 654ms/step - loss: 0.0095 - val_loss: 0.0106
# Epoch 25/50
# 10/10 [==============================] - 7s 704ms/step - loss: 0.0082 - val_loss: 0.0122
# Epoch 26/50
# 10/10 [==============================] - 7s 722ms/step - loss: 0.0070 - val_loss: 0.0139
# Epoch 27/50
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0087 - val_loss: 0.0160
# Epoch 28/50
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0080 - val_loss: 0.0123
# Epoch 29/50
# 10/10 [==============================] - 5s 546ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 30/50
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0062 - val_loss: 0.0106
# Epoch 31/50
# 10/10 [==============================] - 6s 580ms/step - loss: 0.0092 - val_loss: 0.0211
# Epoch 32/50
# 10/10 [==============================] - 6s 562ms/step - loss: 0.0130 - val_loss: 0.0259
# Epoch 33/50
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0146 - val_loss: 0.0124
# Epoch 34/50
# 10/10 [==============================] - 7s 688ms/step - loss: 0.0102 - val_loss: 0.0196
# Epoch 35/50
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0111 - val_loss: 0.0141
# Epoch 36/50
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0077 - val_loss: 0.0121
# Epoch 37/50
# 10/10 [==============================] - 7s 676ms/step - loss: 0.0081 - val_loss: 0.0125
# Epoch 38/50
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0061 - val_loss: 0.0110
# Epoch 39/50
# 10/10 [==============================] - 7s 727ms/step - loss: 0.0054 - val_loss: 0.0094
# Epoch 40/50
# 10/10 [==============================] - 7s 710ms/step - loss: 0.0038 - val_loss: 0.0095
# Epoch 41/50
# 10/10 [==============================] - 7s 709ms/step - loss: 0.0042 - val_loss: 0.0096
# Epoch 42/50
# 10/10 [==============================] - 7s 675ms/step - loss: 0.0036 - val_loss: 0.0086
# Epoch 43/50
# 10/10 [==============================] - 7s 694ms/step - loss: 0.0036 - val_loss: 0.0087
# Epoch 44/50
# 10/10 [==============================] - 6s 660ms/step - loss: 0.0029 - val_loss: 0.0085
# Epoch 45/50
# 10/10 [==============================] - 7s 663ms/step - loss: 0.0030 - val_loss: 0.0082
# Epoch 46/50
# 10/10 [==============================] - 6s 626ms/step - loss: 0.0025 - val_loss: 0.0085
# Epoch 47/50
# 10/10 [==============================] - 6s 610ms/step - loss: 0.0031 - val_loss: 0.0094
# Epoch 48/50
# 10/10 [==============================] - 6s 565ms/step - loss: 0.0030 - val_loss: 0.0091
# Epoch 49/50
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0033 - val_loss: 0.0086
# Epoch 50/50
# 10/10 [==============================] - 5s 525ms/step - loss: 0.0026 - val_loss: 0.0079

# %%
##liq
## univariate 
evaluation_interval = 10
history_liq_uni = model_liq_uni.fit(liq_uni_train, epochs=50, steps_per_epoch=evaluation_interval, \
                                    validation_data=liq_uni_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 8s 607ms/step - loss: 24.3321 - val_loss: 1.1410
# Epoch 2/50
# 10/10 [==============================] - 6s 636ms/step - loss: 1.0961 - val_loss: 0.4358
# Epoch 3/50
# 10/10 [==============================] - 8s 775ms/step - loss: 0.3131 - val_loss: 0.1839
# Epoch 4/50
# 10/10 [==============================] - 7s 746ms/step - loss: 0.1532 - val_loss: 0.1010
# Epoch 5/50
# 10/10 [==============================] - 8s 785ms/step - loss: 0.1189 - val_loss: 0.0633
# Epoch 6/50
# 10/10 [==============================] - 7s 702ms/step - loss: 0.0500 - val_loss: 0.0500
# Epoch 7/50
# 10/10 [==============================] - 7s 725ms/step - loss: 0.0663 - val_loss: 0.0390
# Epoch 8/50
# 10/10 [==============================] - 7s 713ms/step - loss: 0.0302 - val_loss: 0.0341
# Epoch 9/50
# 10/10 [==============================] - 8s 808ms/step - loss: 0.0360 - val_loss: 0.0295
# Epoch 10/50
# 10/10 [==============================] - 7s 762ms/step - loss: 0.0253 - val_loss: 0.0265
# Epoch 11/50
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0272 - val_loss: 0.0235
# Epoch 12/50
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0237 - val_loss: 0.0214
# Epoch 13/50
# 10/10 [==============================] - 7s 758ms/step - loss: 0.0260 - val_loss: 0.0191
# Epoch 14/50
# 10/10 [==============================] - 7s 769ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 15/50
# 10/10 [==============================] - 8s 799ms/step - loss: 0.0204 - val_loss: 0.0160
# Epoch 16/50
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0184 - val_loss: 0.0149
# Epoch 17/50
# 10/10 [==============================] - 7s 700ms/step - loss: 0.0134 - val_loss: 0.0137
# Epoch 18/50
# 10/10 [==============================] - 6s 662ms/step - loss: 0.0194 - val_loss: 0.0129
# Epoch 19/50
# 10/10 [==============================] - 6s 618ms/step - loss: 0.0090 - val_loss: 0.0120
# Epoch 20/50
# 10/10 [==============================] - 6s 616ms/step - loss: 0.0216 - val_loss: 0.0112
# Epoch 21/50
# 10/10 [==============================] - 5s 559ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 22/50
# 10/10 [==============================] - 6s 617ms/step - loss: 0.0196 - val_loss: 0.0100
# Epoch 23/50
# 10/10 [==============================] - 8s 795ms/step - loss: 0.0066 - val_loss: 0.0095
# Epoch 24/50
# 10/10 [==============================] - 7s 715ms/step - loss: 0.0181 - val_loss: 0.0089
# Epoch 25/50
# 10/10 [==============================] - 8s 821ms/step - loss: 0.0060 - val_loss: 0.0088
# Epoch 26/50
# 10/10 [==============================] - 7s 748ms/step - loss: 0.0155 - val_loss: 0.0083
# Epoch 27/50
# 10/10 [==============================] - 7s 707ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 28/50
# 10/10 [==============================] - 8s 867ms/step - loss: 0.0113 - val_loss: 0.0075
# Epoch 29/50
# 10/10 [==============================] - 7s 747ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 30/50
# 10/10 [==============================] - 9s 944ms/step - loss: 0.0097 - val_loss: 0.0070
# Epoch 31/50
# 10/10 [==============================] - 7s 710ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 32/50
# 10/10 [==============================] - 9s 893ms/step - loss: 0.0102 - val_loss: 0.0064
# Epoch 33/50
# 10/10 [==============================] - 8s 803ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 34/50
# 10/10 [==============================] - 6s 603ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 35/50
# 10/10 [==============================] - 6s 589ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 36/50
# 10/10 [==============================] - 7s 678ms/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 37/50
# 10/10 [==============================] - 6s 633ms/step - loss: 0.0095 - val_loss: 0.0058
# Epoch 38/50
# 10/10 [==============================] - 7s 745ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 39/50
# 10/10 [==============================] - 8s 818ms/step - loss: 0.0110 - val_loss: 0.0059
# Epoch 40/50
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 41/50
# 10/10 [==============================] - 8s 779ms/step - loss: 0.0110 - val_loss: 0.0053
# Epoch 42/50
# 10/10 [==============================] - 7s 771ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 43/50
# 10/10 [==============================] - 7s 763ms/step - loss: 0.0101 - val_loss: 0.0050
# Epoch 44/50
# 10/10 [==============================] - 7s 713ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 45/50
# 10/10 [==============================] - 7s 690ms/step - loss: 0.0083 - val_loss: 0.0049
# Epoch 46/50
# 10/10 [==============================] - 6s 615ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 47/50
# 10/10 [==============================] - 6s 569ms/step - loss: 0.0068 - val_loss: 0.0048
# Epoch 48/50
# 10/10 [==============================] - 6s 585ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 49/50
# 10/10 [==============================] - 6s 618ms/step - loss: 0.0061 - val_loss: 0.0045
# Epoch 50/50
# 10/10 [==============================] - 7s 730ms/step - loss: 0.0043 - val_loss: 0.0045

# %%
##liq
## multivariate 
evaluation_interval = 10
history_liq_mult = model_liquid_mult.fit(liq_mult_train, epochs=50, steps_per_epoch=evaluation_interval, \
                                    validation_data=liq_mult_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/50
# 10/10 [==============================] -
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 34/50
# 10/10 [==============================] - 5s 539ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 35/50
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 36/50
# 10/10 [==============================] - 6s 674ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 37/50
# 10/10 [==============================] - 7s 732ms/step - loss: 0.0039 - val_loss: 0.0052
# Epoch 38/50
# 10/10 [==============================] - 7s 695ms/step - loss: 0.0032 - val_loss: 0.0054
# Epoch 39/50
# 10/10 [==============================] - 8s 781ms/step - loss: 0.0040 - val_loss: 0.0068
# Epoch 40/50
# 10/10 [==============================] - 6s 666ms/step - loss: 0.0037 - val_loss: 0.0068
# Epoch 41/50
# 10/10 [==============================] - 7s 697ms/step - loss: 0.0043 - val_loss: 0.0067
# Epoch 42/50
# 10/10 [==============================] - 6s 656ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 43/50
# 10/10 [==============================] - 6s 631ms/step - loss: 0.0044 - val_loss: 0.0062
# Epoch 44/50
# 10/10 [==============================] - 6s 606ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 45/50
# 10/10 [==============================] - 5s 528ms/step - loss: 0.0052 - val_loss: 0.0110
# Epoch 46/50
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0072 - val_loss: 0.0142
# Epoch 47/50
# 10/10 [==============================] - 5s 548ms/step - loss: 0.0096 - val_loss: 0.0130
# Epoch 48/50
# 10/10 [==============================] - 5s 525ms/step - loss: 0.0088 - val_loss: 0.0054
# Epoch 49/50
# 10/10 [==============================] - 5s 537ms/step - loss: 0.0076 - val_loss: 0.0149
# Epoch 50/50
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0090 - val_loss: 0.0069

# %%
def mse(real, pred):
    return mean_squared_error(real, pred)

[mse(model_gas_uni.predict(gas_uni_testX).flatten(), gas_uni_testY.flatten()),\
 mse(model_gas_mult.predict(gas_mult_testX).flatten(), gas_mult_testY.flatten()),\
 mse(model_liq_uni.predict(liq_uni_testX).flatten(), liq_uni_testY.flatten()),\
 mse(model_liquid_mult.predict(liq_mult_testX).flatten(), liq_mult_testY.flatten())]
# Out:
# [0.0041684397, 0.021594329, 0.011442358, 0.03203744]

# %%
## GAS 
# summarize history for loss
plt.plot(history_gas_uni.history['loss'])
plt.plot(history_gas_uni.history['val_loss'])
plt.title('model loss of gas (uni)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history_gas_uni.history['loss'])
plt.plot(history_gas_uni.history['val_loss'])
plt.title('model loss of gas (mult)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## Liquid 
plt.plot(history_liq_uni.history['loss'])
plt.plot(history_liq_uni.history['val_loss'])
plt.title('model loss for liquid (uni)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history_liq_mult.history['loss'])
plt.plot(history_liq_mult.history['val_loss'])
plt.title('model loss for liquid (mult)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## gas testing data set visualization
### univariate 
real_gas_uni = gas_uni_testY.flatten()
pred_gas_uni = model_gas_uni.predict(gas_uni_testX).flatten()
df_plot_gas_uni=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_gas_uni, real_gas_uni]))))
df_plot_gas_uni['ds']=range(0,len(real_gas_uni))
### multivariate 
real_gas_mult = gas_mult_testY.flatten()
pred_gas_mult = model_gas_mult.predict(gas_mult_testX).flatten()
df_plot_gas_mult=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_gas_mult, real_gas_mult]))))
df_plot_gas_mult['ds']=range(0,len(real_gas_mult))
##liquid
## univariate
real_liq_uni = liq_uni_testY.flatten()
pred_liq_uni = model_liq_uni.predict(liq_uni_testX).flatten()
df_plot_liq_uni=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_gas_uni, real_gas_uni]))))
df_plot_liq_uni['ds']=range(0,len(real_liq_uni))
## multivariate 
real_liq_mult = liq_mult_testY.flatten()
pred_liq_mult = model_liquid_mult.predict(liq_mult_testX).flatten()
df_plot_liq_mult=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_liq_mult, real_liq_mult]))))
df_plot_liq_mult['ds']=range(0,len(real_liq_mult))

# %%
start = 0
end = 1000
fig,ax = plt.subplots()
ax.set_title('(GAS) prediction vs real (Uni)')
ax.plot(df_plot_gas_uni['ds'].iloc[start:end], df_plot_gas_uni['prediction'].iloc[start:end], marker=".", label='prediction_gas')
ax.plot(df_plot_gas_uni['ds'].iloc[start:end], df_plot_gas_uni['real'].iloc[start:end], marker=".", label='real_gas')
ax.legend()
fig,ax = plt.subplots()
ax.set_title('(GAS) prediction vs real (Multi)')
ax.plot(df_plot_gas_mult['ds'].iloc[start:end], df_plot_gas_mult['prediction'].iloc[start:end], marker=".", label='prediction_gas')
ax.plot(df_plot_gas_mult['ds'].iloc[start:end], df_plot_gas_mult['real'].iloc[start:end], marker=".", label='real_gas')
ax.legend()

# %%
### liquid before noise, removed data and spikes 
start = 0
end = 1000
fig,ax = plt.subplots()
ax.set_title('(LIQUID) prediction vs real (Uni)')
ax.plot(df_plot_liq_uni['ds'].iloc[start:end], df_plot_liq_uni['prediction'].iloc[start:end], marker=".", label='prediction_liquid')
ax.plot(df_plot_liq_uni['ds'].iloc[start:end], df_plot_liq_uni['real'].iloc[start:end], marker=".", label='real_liquid')
ax.legend()
fig,ax = plt.subplots()
ax.set_title('(LIQUID) prediction vs real (Multi)')
ax.plot(df_plot_liq_mult['ds'].iloc[start:end], df_plot_liq_mult['prediction'].iloc[start:end], marker=".", label='prediction_liquid')
ax.plot(df_plot_liq_mult['ds'].iloc[start:end], df_plot_liq_mult['real'].iloc[start:end], marker=".", label='real_liquid')
ax.legend()

# %% [markdown]
# #### Well data

# %%
import os
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM/src")
import preprocessing 
from preprocessing import read_data_slugging, read_data_well
import pandas as pd
import configuration 
from configuration import configure
import numpy as np

# %%
dt, headers, _ = read_data_well('welltest.csv', params=[900, 0, 5e-3, 0], is_not_clean=True)

# %%
dfy = pd.DataFrame.from_dict(dict(zip(headers, dt[0].T)))
for i in [1,2, 3, 4]:
    tmp = pd.DataFrame.from_dict(dict(zip(headers, dt[i].T)))
    dfy = pd.concat([dfy,tmp], axis=0)
dfy = dfy.drop(columns={'DateTime'}, axis=1)
train_uni_oil= np.array(dfy['Qo (m3/day)'])
train_uni_water= np.array(dfy['Qw (m3/day)']) 
train_uni_gas= np.array(dfy['Qg (m3/day)']) 
## multivariate 
train_mult_oil = dfy.iloc[:, 0:3]
train_mult_water = pd.concat([dfy.iloc[:, 0:1], dfy['Qw (m3/day)']], axis=1)
train_mult_gas = pd.concat([dfy.iloc[:, 0:2], dfy['Qg (m3/day)']], axis=1)

# %%
sm = 0
for i in dt:
    sm += len(i)
    print(sm)
# Out:
# 1797
# 3191
# 4557
# 5535
# 7933

# %%
gas_mult_train_well, gas_mult_val_well, gas_mult_testX_well, gas_mult_testY_well = configure(train_mult_gas,\
                                                                        params = [0, 1797, 1797, 3191,3191, 4557 ], multi = True, column_index=2)
# Out:
# (300, 300, 2) (300, 5, 1) (219, 300, 2) (219, 5, 1) (214, 300, 2) (214, 5, 1)
# (300, 300, 2) (300, 5, 1) (219, 300, 2) (219, 5, 1) (214, 300, 2) (214, 5, 1)

# %%
oil_uni_train, oil_uni_val, oil_uni_testX, oil_uni_testY = configure(train_uni_oil, \
                                                                      params = [0, 4557, 5535, 7934], multi = False)
train_mult_oil = train_mult_oil.drop('DateTime', axis=1)
oil_mult_train, oil_mult_val, oil_mult_testX, oil_mult_testY = configure(train_mult_oil,\
                                                                         params = [0, 4557, 5535, 7933], multi = True)
# Out:
# /Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM/src/preprocessing.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(data), np.array(labels)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-073060f536c1> in <module>
#       3 train_mult_oil = train_mult_oil.drop('DateTime', axis=1)
#       4 oil_mult_train, oil_mult_val, oil_mult_testX, oil_mult_testY = configure(train_mult_oil,\
# ----> 5                                                                          params = [0, 4557, 5535, 7933], multi = True)
#
# ~/Documents/GitHub/DeepAR_Prophet_VFM/src/configuration.py in configure(data, params, past_history, forecast_horizon, batch_size, multi)
#      25         valY_mult = valY_mult.astype(np.float32)
#      26         testX_mult = testX_mult.astype(np.float32)
# ---> 27         testY_mult = testY_mult.astype(np.float32)
#      28         # to build data set
#      29         train_data_mult = tf.data.Dataset.from_tensor_slices((x_mult, y_mult)).cache().batch(batch_size).repeat()
#
# ValueError: setting an array element with a sequence.

# %%
start  = 0
end = len(dfy)
for i in headers[1:]:
    fig,ax = plt.subplots()
    ax.set_title('orginal data of %s with spikes'%i)
    ax.plot(dfy['DateTime'].iloc[start:end], dfy[i].iloc[start:end], marker=".", label='%s'%i)
    ax.legend()

# %%
start  = 0
end = len(dfy)
for i in headers[1:]:
    fig,ax = plt.subplots()
    ax.set_title('orginal data of %s with spikes'%i)
    ax.plot(dfy['DateTime'].iloc[start:end], dfy[i].iloc[start:end], marker=".", label='%s'%i)
    ax.legend()

# %%
fp,headers, _ = read_data('welltest.csv')

# %%
os.chdir("/Users/ridhaalkhabaz/Documents/GitHub/DeepAR_Prophet_VFM")
fp, headers, scaler = read_data('welltest.csv')
df = pd.DataFrame.from_dict(dict(zip(headers, fp[0].T)))
for i in [1,2, 3, 4]:
    tmp = pd.DataFrame.from_dict(dict(zip(headers, fp[i].T)))
    df = pd.concat([df,tmp], axis=0)
df = df.drop(['DateTime'], axis=1)
# test = pd.DataFrame.from_dict(dict(zip(headers, fp[3].T)))
# test = test.drop(['DateTime'], axis=1)
## univariate training
train_uni_oil= np.array(df['Qo (m3/day)'])
train_uni_water= np.array(df['Qw (m3/day)']) 
train_uni_gas= np.array(df['Qg (m3/day)']) 
## multivariate 
train_mult_oil = df.iloc[:, 0:3]
train_mult_water = pd.concat([df.iloc[:, 0:1], df['Qw (m3/day)']], axis=1)
train_mult_gas = pd.concat([df.iloc[:, 0:2], df['Qg (m3/day)']], axis=1)

# %%
start  = 0
end = len(df)
for i in headers[1:]:
    fig,ax = plt.subplots()
    ax.set_title('orginal data of %s with spikes'%i)
    ax.plot(df['DateTime'].iloc[start:end], df[i].iloc[start:end], marker=".", label='%s'%i)
    ax.legend()

# %% [markdown]
# ### Models parameters and structure:

# %%
# Model Hyperparemeters (general hyperparameters)
FORECAST_HORIZON = 5 #secs 
PAST_HISTORY = 300
BATCH_SIZE = 64

# %%
##  Oil (univariate)
INPUT_DIMSION = 1
model_oil_uni = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_oil_uni.summary()
model_oil_uni.compile('adam', 'mse')
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_10 (TCN)                 (None, 64)                136256
# _________________________________________________________________
# dense_10 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 136,581
# Trainable params: 136,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
## multivariate 
INPUT_DIMSION = 3
model_oil_mult = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_oil_mult.summary()
model_oil_mult.compile('adam', 'mse')
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_11 (TCN)                 (None, 64)                136768
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 137,093
# Trainable params: 137,093
# Non-trainable params: 0
# _________________________________________________________________

# %%
##  water (univariate)
INPUT_DIMSION = 1
model_water_uni = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_water_uni.summary()
model_water_uni.compile('adam', 'mse')
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_12 (TCN)                 (None, 64)                136256
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 136,581
# Trainable params: 136,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
##  water (multivariate)
INPUT_DIMSION = 2
model_water_mult = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_water_mult.summary()
model_water_mult.compile('adam', 'mse')
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_16 (TCN)                 (None, 64)                136512
# _________________________________________________________________
# dense_16 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 136,837
# Trainable params: 136,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
##  gas (univariate)
INPUT_DIMSION = 1
model_gas_uni = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_gas_uni.summary()
model_gas_uni.compile('adam', 'mse')
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_14 (TCN)                 (None, 64)                136256
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 136,581
# Trainable params: 136,581
# Non-trainable params: 0
# _________________________________________________________________

# %%
##  gas (multivariate)
INPUT_DIMSION = 3
model_gas_mult = Sequential(
    layers=[
        TCN(input_shape=(PAST_HISTORY, INPUT_DIMSION)),  # output.shape = (batch, 64)
        Dense(FORECAST_HORIZON) # output.shape = (batch, output_timesteps, 64)
    ]
)

model_gas_mult.summary()
model_gas_mult.compile('adam', 'mse')
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_15 (TCN)                 (None, 64)                136768
# _________________________________________________________________
# dense_15 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 137,093
# Trainable params: 137,093
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Data configurations:

# %%
def univariate_data(tseries, start_index, end_index, history_size, forecast_horizon, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size

    for i in range(start_index, end_index - forecast_horizon + 1, forecast_horizon):
        end = i+history_size
        if len(tseries[i:end]) < history_size:
            break
        data.append(tseries[i:end].reshape(history_size, 1))
        labels.append(tseries[i:i + forecast_horizon])

    return np.array(data), np.array(labels)
def multivariate_data(tseries, start_index, end_index, history_size, forecast_horizon):
    data = []
    labels = []
    for i in range(start_index, end_index -history_size, forecast_horizon):
        end = i+history_size
        if len(tseries[end:end+forecast_horizon, 0:2]) <5:
            break
        data.append(tseries[i:end, 0:2])
        labels.append(tseries[end:end+forecast_horizon, 2:])
    return np.array(data), np.array(labels)

def configure(data, params = [0, 4557, 5535, 7933], multi = False):
    if multi:
        x_mult, y_mult= multivariate_data(np.array(data), params[0], params[1], PAST_HISTORY, FORECAST_HORIZON)
        valX_mult , valY_mult = multivariate_data(np.array(data), params[1], params[2], PAST_HISTORY, FORECAST_HORIZON)
        testX_mult, testY_mult = multivariate_data(np.array(data), params[2], params[3], PAST_HISTORY, FORECAST_HORIZON)
        # to avoid combatibility issues
        x_mult = x_mult.astype(np.float32)
        y_mult = y_mult.astype(np.float32)
        valX_mult = valX_mult.astype(np.float32)
        valY_mult = valY_mult.astype(np.float32)
        testX_mult = testX_mult.astype(np.float32)
        testY_mult = testY_mult.astype(np.float32)
        # to build data set
        train_data_mult = tf.data.Dataset.from_tensor_slices((x_mult, y_mult)).cache().batch(BATCH_SIZE).repeat()
        val_data_mult = tf.data.Dataset.from_tensor_slices((valX_mult, valY_mult)).batch(BATCH_SIZE).repeat()
        return train_data_mult, val_data_mult, testX_mult, testY_mult
    # for univariate 
    x_uni, y_uni = univariate_data(np.array(data), params[0], params[1], PAST_HISTORY, FORECAST_HORIZON)
    valX_uni , valY_uni = univariate_data(np.array(data), params[1], params[2], PAST_HISTORY, FORECAST_HORIZON)
    testX_uni, testY_uni = univariate_data(np.array(data),params[2], params[3], PAST_HISTORY, FORECAST_HORIZON)
    # to avoid combatibality issues
    x_uni = x_uni.astype(np.float32)
    y_uni = y_uni.astype(np.float32)
    valX_uni = valX_uni.astype(np.float32)
    valY_uni = valY_uni.astype(np.float32)
    testX_uni = testX_uni.astype(np.float32)
    testY_uni = testY_uni.astype(np.float32)
    # to build data set 
    train_data_uni = tf.data.Dataset.from_tensor_slices((x_uni, y_uni)).cache().batch(BATCH_SIZE).repeat()
    val_data_uni = tf.data.Dataset.from_tensor_slices((valX_uni, valY_uni)).batch(BATCH_SIZE).repeat()
    return train_data_uni, val_data_uni, testX_uni, testY_uni

# %%
oil_uni_train, oil_uni_val, oil_uni_testX, oil_uni_testY = configure(train_uni_oil, \
                                                                      params = [0, 4557, 5535, 7934], multi = False)
train_mult_oil = train_mult_oil.drop('DateTime', axis=0)
oil_mult_train, oil_mult_val, oil_mult_testX, oil_mult_testY = configure(train_mult_oil,\
                                                                         params = [0, 4557, 5535, 7933], multi = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-76d6884ad4b8> in <module>
#       1 oil_uni_train, oil_uni_val, oil_uni_testX, oil_uni_testY = configure(train_uni_oil, \
#       2                                                                       params = [0, 4557, 5535, 7934], multi = False)
# ----> 3 train_mult_oil = train_mult_oil.drop('DateTime', axis=0)
#       4 oil_mult_train, oil_mult_val, oil_mult_testX, oil_mult_testY = configure(train_mult_oil,\
#       5                                                                          params = [0, 4557, 5535, 7933], multi = True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4204                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4205                 if errors == "raise" and labels_missing:
# -> 4206                     raise KeyError(f"{labels} not found in axis")
#    4207
#    4208             slicer = [slice(None)] * self.ndim
#
# KeyError: "['DateTime'] not found in axis"

# %%
oil_uni_val
# Out:
# <RepeatDataset shapes: ((None, 300, 1), (None, 5)), types: (tf.float32, tf.float32)>

# %%
## Oil
oil_uni_train, oil_uni_val, oil_uni_testX, oil_uni_testY = configure(train_uni_oil, \
                                                                     params = [0, 4557, 5535, 7934], multi = False)
oil_mult_train, oil_mult_val, oil_mult_testX, oil_mult_testY = configure(train_mult_oil,\
                                                                         params = [0, 4557, 5535, 7933], multi = True)
# Water 
water_uni_train, water_uni_val, water_uni_testX, water_uni_testY = configure(train_uni_water, \
                                                                     params = [0, 4557, 5535, 7934], multi = False)
water_mult_train, water_mult_val, water_mult_testX, water_mult_testY = configure(train_mult_water,\
                                                                         params = [0, 4557, 5535, 7933], multi = True)
# Gas
# Water 
gas_uni_train, gas_uni_val, gas_uni_testX, gas_uni_testY = configure(train_uni_gas, \
                                                                     params = [0, 4557, 5535, 7934], multi = False)
gas_mult_train, gas_mult_val, gas_mult_testX, gas_mult_testY = configure(train_mult_gas,\
                                                                         params = [0, 4557, 5535, 7933], multi = True)

# %% [markdown]
# #### Model fitting:

# %%
## oil 
## univariate
evaluation_interval = 10
history_oil_uni = model_oil_uni.fit(oil_uni_train, epochs=100, steps_per_epoch=evaluation_interval,\
                                    validation_data=oil_uni_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/100
# 10/10 [==============================] -
ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 32/100
# 10/10 [==============================] - 8s 771ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 33/100
# 10/10 [==============================] - 9s 903ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 34/100
# 10/10 [==============================] - 9s 866ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 35/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0070 - val_loss: 0.0035
# Epoch 36/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 37/100
# 10/10 [==============================] - 9s 936ms/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 38/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 39/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 40/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 41/100
# 10/10 [==============================] - 9s 888ms/step - loss: 0.0042 - val_loss: 0.0063
# Epoch 42/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0075 - val_loss: 0.0034
# Epoch 43/100
# 10/10 [==============================] - 7s 766ms/step - loss: 0.0028 - val_loss: 0.0049
# Epoch 44/100
# 10/10 [==============================] - 6s 619ms/step - loss: 0.0031 - val_loss: 0.0081
# Epoch 45/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 46/100
# 10/10 [==============================] - 7s 712ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 47/100
# 10/10 [==============================] - 6s 644ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 48/100
# 10/10 [==============================] - 6s 652ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 49/100
# 10/10 [==============================] - 7s 702ms/step - loss: 0.0077 - val_loss: 0.0030
# Epoch 50/100
# 10/10 [==============================] - 7s 719ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 51/100
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 52/100
# 10/10 [==============================] - 7s 737ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 53/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 54/100
# 10/10 [==============================] - 6s 581ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 55/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 56/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0055 - val_loss: 0.0030
# Epoch 57/100
# 10/10 [==============================] - 5s 561ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 58/100
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 59/100
# 10/10 [==============================] - 7s 677ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 60/100
# 10/10 [==============================] - 6s 588ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 61/100
# 10/10 [==============================] - 6s 624ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 62/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 63/100
# 10/10 [==============================] - 6s 670ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 64/100
# 10/10 [==============================] - 8s 773ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 65/100
# 10/10 [==============================] - 8s 776ms/step - loss: 0.0015 - val_loss: 0.0042
# Epoch 66/100
# 10/10 [==============================] - 8s 793ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 67/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 68/100
# 10/10 [==============================] - 9s 928ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 69/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 70/100
# 10/10 [==============================] - 8s 790ms/step - loss: 0.0049 - val_loss: 0.0027
# Epoch 71/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 72/100
# 10/10 [==============================] - 7s 723ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 73/100
# 10/10 [==============================] - 9s 976ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 74/100
# 10/10 [==============================] - 9s 899ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 75/100
# 10/10 [==============================] - 8s 810ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 76/100
# 10/10 [==============================] - 8s 826ms/step - loss: 0.0034 - val_loss: 0.0034
# Epoch 77/100
# 10/10 [==============================] - 7s 700ms/step - loss: 0.0049 - val_loss: 0.0036
# Epoch 78/100
# 10/10 [==============================] - 8s 878ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 79/100
# 10/10 [==============================] - 7s 751ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 80/100
# 10/10 [==============================] - 7s 715ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 81/100
# 10/10 [==============================] - 8s 864ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 82/100
# 10/10 [==============================] - 9s 901ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 83/100
# 10/10 [==============================] - 7s 642ms/step - loss: 0.0027 - val_loss: 0.0074
# Epoch 84/100
# 10/10 [==============================] - 8s 776ms/step - loss: 0.0051 - val_loss: 0.0024
# Epoch 85/100
# 10/10 [==============================] - 6s 629ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 86/100
# 10/10 [==============================] - 7s 667ms/step - loss: 0.0018 - val_loss: 0.0051
# Epoch 87/100
# 10/10 [==============================] - 7s 725ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 88/100
# 10/10 [==============================] - 8s 835ms/step - loss: 0.0027 - val_loss: 0.0033
# Epoch 89/100
# 10/10 [==============================] - 8s 870ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 90/100
# 10/10 [==============================] - 7s 701ms/step - loss: 0.0032 - val_loss: 0.0025
# Epoch 91/100
# 10/10 [==============================] - 9s 894ms/step - loss: 0.0048 - val_loss: 0.0037
# Epoch 92/100
# 10/10 [==============================] - 8s 833ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 93/100
# 10/10 [==============================] - 8s 848ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 94/100
# 10/10 [==============================] - 8s 794ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 95/100
# 10/10 [==============================] - 8s 803ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 96/100
# 10/10 [==============================] - 7s 692ms/step - loss: 0.0019 - val_loss: 0.0037
# Epoch 97/100
# 10/10 [==============================] - 6s 552ms/step - loss: 0.0032 - val_loss: 0.0049
# Epoch 98/100
# 10/10 [==============================] - 5s 544ms/step - loss: 0.0043 - val_loss: 0.0027
# Epoch 99/100
# 10/10 [==============================] - 6s 648ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 100/100
# 10/10 [==============================] - 5s 533ms/step - loss: 0.0016 - val_loss: 0.0044

# %%
## oil 
## multivariate 0try pressure only and tempreture only 
evaluation_interval = 10
history_oil_mult = model_oil_mult.fit(oil_mult_train, epochs=100, steps_per_epoch=evaluation_interval, validation_data=oil_mult_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 13s 858ms/step - loss: 17.5694 - val_loss: 0.6086
# Epoch 2/100
# 10/10 [==============================] - 7s 685ms/step - loss: 0.4986 - val_loss: 0.3136
# Epoch 3/100
# 10/10 [==============================] - 6s 664ms/step - loss: 0.1268 - val_loss: 0.1848
# Epoch 4/100
# 10/10 [==============================] - 7s 739ms/step - loss: 0.0740 - val_loss: 0.0774
# Epoch 5/100
# 10/10 [==============================] - 7s 685ms/step - loss: 0.0401 - val_loss: 0.0668
# Epoch 6/100
# 10/10 [==============================] - 7s 695ms/step - loss: 0.0399 - val_loss: 0.0594
# Epoch 7/100
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0445 - val_loss: 0.0493
# Epoch 8/100
# 10/10 [==============================] - 7s 721ms/step - loss: 0.0195 - val_loss: 0.0624
# Epoch 9/100
# 10/10 [==============================] - 7s 709ms/step - loss: 0.0306 - val_loss: 0.0451
# Epoch 10/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0385 - val_loss: 0.0632
# Epoch 11/100
# 10/10 [==============================] - 9s 955ms/step - loss: 0.0271 - val_loss: 0.0269
# Epoch 12/100
# 10/10 [==============================] - 9s 930ms/step - loss: 0.0190 - val_loss: 0.0443
# Epoch 13/100
# 10/10 [==============================] - 8s 867ms/step - loss: 0.0286 - val_loss: 0.0543
# Epoch 14/100
# 10/10 [==============================] - 7s 718ms/step - loss: 0.0294 - val_loss: 0.0379
# Epoch 15/100
# 10/10 [==============================] - 7s 691ms/step - loss: 0.0123 - val_loss: 0.0400
# Epoch 16/100
# 10/10 [==============================] - 6s 632ms/step - loss: 0.0211 - val_loss: 0.0515
# Epoch 17/100
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0269 - val_loss: 0.0682
# Epoch 18/100
# 10/10 [==============================] - 7s 683ms/step - loss: 0.0187 - val_loss: 0.0268
# Epoch 19/100
# 10/10 [==============================] - 7s 653ms/step - loss: 0.0158 - val_loss: 0.0241
# Epoch 20/100
# 10/10 [==============================] - 6s 577ms/step - loss: 0.0226 - val_loss: 0.1407
# Epoch 21/100
# 10/10 [==============================] - 6s 573ms/step - loss: 0.0300 - val_loss: 0.0412
# Epoch 22/100
# 10/10 [==============================] - 6s 636ms/step - loss: 0.0097 - val_loss: 0.0276
# Epoch 23/100
# 10/10 [==============================] - 6s 652ms/step - loss: 0.0156 - val_loss: 0.0940
# Epoch 24/100
# 10/10 [==============================] - 8s 832ms/step - loss: 0.0306 - val_loss: 0.1047
# Epoch 25/100
# 10/10 [==============================] - 9s 879ms/step - loss: 0.0200 - val_loss: 0.0235
# Epoch 26/100
# 10/10 [==============================] - 8s 783ms/step - loss: 0.0161 - val_loss: 0.0223
# Epoch 27/100
# Epoch 86/100
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 87/100
# 10/10 [==============================] - 6s 561ms/step - loss: 0.0039 - val_loss: 0.0067
# Epoch 88/100
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0026 - val_loss: 0.0055
# Epoch 89/100
# 10/10 [==============================] - 5s 510ms/step - loss: 0.0022 - val_loss: 0.0061
# Epoch 90/100
# 10/10 [==============================] - 5s 506ms/step - loss: 0.0031 - val_loss: 0.0053
# Epoch 91/100
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 92/100
# 10/10 [==============================] - 7s 671ms/step - loss: 0.0017 - val_loss: 0.0054
# Epoch 93/100
# 10/10 [==============================] - 6s 605ms/step - loss: 0.0025 - val_loss: 0.0069
# Epoch 94/100
# 10/10 [==============================] - 6s 638ms/step - loss: 0.0038 - val_loss: 0.0051
# Epoch 95/100
# 10/10 [==============================] - 6s 645ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 96/100
# 10/10 [==============================] - 6s 632ms/step - loss: 0.0022 - val_loss: 0.0068
# Epoch 97/100
# 10/10 [==============================] - 6s 633ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 98/100
# 10/10 [==============================] - 6s 606ms/step - loss: 0.0031 - val_loss: 0.0051
# Epoch 99/100
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 100/100
# 10/10 [==============================] - 5s 492ms/step - loss: 0.0024 - val_loss: 0.0082

# %%
## water 
## univariate 
evaluation_interval = 10
history_water_uni = model_water_uni.fit(water_uni_train, epochs=150, steps_per_epoch=evaluation_interval,\
                                    validation_data=water_uni_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 6s 459ms/step - loss: 0.3033 - val_loss: 0.1475
# Epoch 2/150
# 10/10 [==============================] - 4s 387ms/step - loss: 0.3561 - val_loss: 1.3814
# Epoch 3/150
# 10/10 [==============================] - 4s 385ms/step - loss: 0.2164 - val_loss: 0.2229
# Epoch 4/150
# 10/10 [==============================] - 4s 406ms/step - loss: 0.0806 - val_loss: 0.0782
# Epoch 5/150
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0539 - val_loss: 0.0996
# Epoch 6/150
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0902 - val_loss: 0.1620
# Epoch 7/150
# 10/10 [==============================] - 4s 380ms/step - loss: 0.0428 - val_loss: 0.0334
# Epoch 8/150
# 10/10 [==============================] - 4s 408ms/step - loss: 0.0187 - val_loss: 0.0712
# Epoch 9/150
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0408 - val_loss: 0.3432
# Epoch 10/150
# 10/10 [==============================] - 4s 408ms/step - loss: 0.0766 - val_loss: 0.2474
# Epoch 11/150
# 10/10 [==============================] - 4s 411ms/step - loss: 0.0613 - val_loss: 0.0681
# Epoch 12/150
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0455 - val_loss: 0.0528
# Epoch 13/150
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0717 - val_loss: 0.0873
# Epoch 14/150
# 10/10 [==============================] - 4s 387ms/step - loss: 0.
# 10/10 [==============================] - 4s 413ms/step - loss: 0.0059 - val_loss: 0.0200
# Epoch 145/150
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0054 - val_loss: 0.0375
# Epoch 146/150
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0130 - val_loss: 0.0215
# Epoch 147/150
# 10/10 [==============================] - 4s 393ms/step - loss: 0.0102 - val_loss: 0.0164
# Epoch 148/150
# 10/10 [==============================] - 4s 414ms/step - loss: 0.0037 - val_loss: 0.0246
# Epoch 149/150
# 10/10 [==============================] - 4s 397ms/step - loss: 0.0052 - val_loss: 0.0332
# Epoch 150/150
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0113 - val_loss: 0.0249

# %%
## multivariate 
evaluation_interval = 10
history_water_mult = model_water_mult.fit(water_mult_train, epochs=150, steps_per_epoch=evaluation_interval,\
                                    validation_data=water_mult_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 6s 444ms/step - loss: 2.1840 - val_loss: 0.6035
# Epoch 2/150
# 10/10 [==============================] - 4s 380ms/step - loss: 0.2938 - val_loss: 0.8667
# Epoch 3/150
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1232 - val_loss: 0.5144
# Epoch 4/150
# 10/10 [==============================] - 4s 402ms/step - loss: 0.0766 - val_loss: 0.1894
# Epoch 5/150
# 10/10 [==============================] - 4s 380ms/step - loss: 0.1070 - val_loss: 0.3657
# Epoch 6/150
# 10/10 [==============================] - 4s 384ms/step - loss: 0.1061 - val_loss: 0.4005
# Epoch 7/150
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0976 - val_loss: 0.0706
# Epoch 8/150
# 10/10 [==============================] - 4s 414ms/step - loss: 0.0352 - val_loss: 0.0728
# Epoch 9/150
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0399 - val_loss: 0.1394
# Epoch 10/150
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0405 - val_loss: 0.1208
# Epoch 11/150
# 10/10 [==============================] - 4s 412ms/step - loss: 0.0337 - val_loss: 0.0434
# Epoch 12/150
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0302 - val_loss: 0.1969
# Epoch 13/150
# 10/10 [==============================] - 4s 405ms/step - loss: 0.0520 - val_loss: 0.0767
# Epoch 14/150
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0300 - val_loss: 0.0262
# Epoch 15/150
# 10/10 [==============================] - 4s 411ms/step - loss: 0.0138 - val_loss: 0.0820
# Epoch 16/150
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0305 - val_loss: 0.1734
# Epoch 17/150
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0370 - val_loss: 0.0537
# Epoch 18/150
# 10/10 [==============================] - 4s 413ms/step - loss: 0.0202 - val_loss: 0.0246
# Epoch 19/150
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0179 - val_loss: 0.0953
# Epoch 20/150
# 10/10 [==============================] - 4s 387ms/step - loss: 0.
# Epoch 148/150
# 10/10 [==============================] - 4s 456ms/step - loss: 0.0027 - val_loss: 0.0075
# Epoch 149/150
# 10/10 [==============================] - 4s 416ms/step - loss: 0.0033 - val_loss: 0.0136
# Epoch 150/150
# 10/10 [==============================] - 4s 422ms/step - loss: 0.0041 - val_loss: 0.0049

# %%
## gas 
## univariate 
evaluation_interval = 10
history_gas_uni = model_gas_uni.fit(gas_uni_train, epochs=100, steps_per_epoch=evaluation_interval,\
                                    validation_data=gas_uni_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 16s 1s/step - loss: 0.8872 - val_loss: 1.2851
# Epoch 2/100
# 10/10 [==============================] - 7s 716ms/step - loss: 0.7125 - val_loss: 0.4461
# Epoch 3/100
# 10/10 [==============================] - 6s 644ms/step - loss: 0.1705 - val_loss: 0.4306
# Epoch 4/100
# 10/10 [==============================] - 8s 839ms/step - loss: 0.1118 - val_loss: 0.1591
# Epoch 5/100
# 10/10 [==============================] - 8s 867ms/step - loss: 0.1607 - val_loss: 0.2801
# Epoch 6/100
# 10/10 [==============================] - 10s 985ms/step - loss: 0.1511 - val_loss: 1.1006
# Epoch 7/100
# 10/10 [==============================] - 9s 904ms/step - loss: 0.2300 - val_loss: 0.1308
# Epoch 8/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0658 - val_loss: 0.1187
# Epoch 9/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0966 - val_loss: 0.4715
# Epoch 10/100
# 10/10 [==============================] - 9s 827ms/step - loss: 0.1093 - val_loss: 0.5219
# Epoch 11/100
# 10/10 [==============================] - 8s 812ms/step - loss: 0.1373 - val_loss: 0.2379
# Epoch 12/100
# 10/10 [==============================] - 7s 714ms/step - loss: 0.2455 - val_loss: 0.6236
# Epoch 13/100
# 10/10 [==============================] - 8s 819ms/step - loss: 0.2433 - val_loss: 0.2172
# Epoch 14/100
# 10/10 [==============================] - 9s 881ms/step - loss: 0.1485 - val_loss: 0.1017
# Epoch 15/100
# 10/10 [==============================] - 9s 971ms/step - loss: 0.0309 - val_loss: 0.1180
# Epoch 16/100
# 10/10 [==============================] - 10s 991ms/step - loss: 0.0493 - val_loss: 0.1069
# Epoch 17/100
# 10/10 [==============================] - 9s 867ms/step - loss: 0.0552 - val_loss: 0.0850
# Epoch 18/100
# 10/10 [==============================] - 9s 933ms/step - loss: 0.0330 - val_loss: 0.0401
# Epoch 19/100
# 10/10 [==============================] - 9s 871ms/step - loss: 0.0290 - val_loss: 0.0683
# Epoch 20/100
# 10/10 [==============================] - 8s 828ms/step - loss: 0.0479 - val_loss: 0.0711
# Epoch 21/100
# 10/10 [==============================] - 7s 696ms/step - loss: 0.0427 - val_loss: 0.0293
# Epoch 22/100
# 10/10 [==============================] - 9s 906ms/step - loss: 0.0174 - val_loss: 0.0486
# Epoch 23/100
# 10/10 [==============================] - 7s 705ms/step - loss: 0.0168 - val_loss: 0.0807
# Epoch 24/100
# 10/10 [==============================] - 8s 814ms/step - loss: 0.0261 - val_loss: 0.0284
# Epoch 25/100
# 10/10 [==============================] - 8s 859ms/step - loss: 0.0240 - val_loss: 0.0381
# Epoch 26/100
# 10/10 [==============================] - 9s 915ms/step - loss: 0.0136 - val_loss: 0.0789
# Epoch 27/100
# 10/10 [==============================] - 9s 968ms/step - loss: 0.0336 - val_loss: 0.0280
# Epoch 28/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0409 - val_loss: 0.0415
# Epoch 29/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0094 - val_loss: 0.0717
# Epoch 30/100
# 10/10 [==============================] - 9s 872ms/step - loss: 0.0210 - val_loss: 0.0330
# Epoch 31/100
# 10/10 [==============================] - 9s 937ms/step - loss: 0.0192 - val_loss: 0.0502
# Epoch 32/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0158 - val_loss: 0.0343
# Epoch 33/100
# 10/10 [==============================] - 10s 988ms/step - loss: 0.0147 - val_loss: 0.0332
# Epoch 34/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0280 - val_loss: 0.0523
# Epoch 35/100
# 10/10 [==============================] - 9s 921ms/step - loss: 0.0287 - val_loss: 0.0275
# Epoch 36/100
# 10/10 [==============================] - 9s 912ms/step - loss: 0.0104 - val_loss: 0.0455
# Epoch 37/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0107 - val_loss: 0.0558
# Epoch 38/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.0153 - val_loss: 0.0252
# Epoch 39/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0152 - val_loss: 0.0376
# Epoch 40/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.0089 - val_loss: 0.0560
# Epoch 41/100
# 10/10 [==============================] - 9s 869ms/step - loss: 0.0208 - val_loss: 0.0276
# Epoch 42/100
# 10/10 [==============================] - 10s 960ms/step - loss: 0.0259 - val_loss: 0.0344
# Epoch 43/100
# 10/10 [==============================] - 10s 980ms/step - loss: 0.0069 - val_loss: 0.0581
# Epoch 44/100
# 10/10 [==============================] - 9s 900ms/step - loss: 0.0137 - val_loss: 0.0425
# Epoch 45/100
# 10/10 [==============================] - 9s 901ms/step - loss: 0.0140 - val_loss: 0.0362
# Epoch 46/100
# 10/10 [==============================] - 8s 777ms/step - loss: 0.0126 - val_loss: 0.0362
# Epoch 47/100
# 10/10 [==============================] - 6s 666ms/step - loss: 0.0106 - val_loss: 0.0445
# Epoch 48/100
# 10/10 [==============================] - 7s 652ms/step - loss: 0.0217 - val_loss: 0.0374
# Epoch 49/100
# 10/10 [==============================] - 7s 695ms/step - loss: 0.0230 - val_loss: 0.0291
# Epoch 50/100
# 10/10 [==============================] - 6s 657ms/step - loss: 0.0071 - val_loss: 0.0512
# Epoch 51/100
# 10/10 [==============================] - 6s 602ms/step - loss: 0.0107 - val_loss: 0.0429
# Epoch 52/100
# 10/10 [==============================] - 8s 801ms/step - loss: 0.0118 - val_loss: 0.0303
# Epoch 53/100
# 10/10 [==============================] - 8s 809ms/step - loss: 0.0126 - val_loss: 0.0355
# Epoch 54/100
# 10/10 [==============================] - 6s 630ms/step - loss: 0.0090 - val_loss: 0.0524
# Epoch 55/100
# 10/10 [==============================] - 9s 947ms/step - loss: 0.0193 - val_loss: 0.0503
# Epoch 56/100
# 10/10 [==============================] - 6s 649ms/step - loss: 0.0257 - val_loss: 0.0307
# Epoch 57/100
# 10/10 [==============================] - 10s 1s/step - loss: 0.
# 10/10 [==============================] - 6s 606ms/step - loss: 0.0135 - val_loss: 0.0285
# Epoch 91/100
# 10/10 [==============================] - 6s 624ms/step - loss: 0.0183 - val_loss: 0.0311
# Epoch 92/100
# 10/10 [==============================] - 7s 734ms/step - loss: 0.0054 - val_loss: 0.0464
# Epoch 93/100
# 10/10 [==============================] - 6s 640ms/step - loss: 0.0072 - val_loss: 0.0359
# Epoch 94/100
# 10/10 [==============================] - 6s 657ms/step - loss: 0.0087 - val_loss: 0.0298
# Epoch 95/100
# 10/10 [==============================] - 7s 680ms/step - loss: 0.0095 - val_loss: 0.0385
# Epoch 96/100
# 10/10 [==============================] - 6s 631ms/step - loss: 0.0070 - val_loss: 0.0461
# Epoch 97/100
# 10/10 [==============================] - 6s 611ms/step - loss: 0.0149 - val_loss: 0.0334
# Epoch 98/100
# 10/10 [==============================] - 6s 631ms/step - loss: 0.0176 - val_loss: 0.0292
# Epoch 99/100
# 10/10 [==============================] - 6s 625ms/step - loss: 0.0054 - val_loss: 0.0504
# Epoch 100/100
# 10/10 [==============================] - 7s 769ms/step - loss: 0.0083 - val_loss: 0.0365

# %%
## multivariate 
evaluation_interval = 10
history_gas_mult = model_gas_mult.fit(gas_mult_train, epochs=100, steps_per_epoch=evaluation_interval,\
                                    validation_data=gas_mult_val, validation_steps=evaluation_interval)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 14s 871ms/step - loss: 8.4698 - val_loss: 1.8648
# Epoch 2/100
# 10/10 [==============================] - 9s 880ms/step - loss: 0.7332 - val_loss: 0.3247
# Epoch 3/100
# 10/10 [==============================] - 9s 857ms/step - loss: 0.2638 - val_loss: 0.2092
# Epoch 4/100
# 10/10 [==============================] - 7s 687ms/step - loss: 0.1007 - val_loss: 0.1153
# Epoch 5/100
# 10/10 [==============================] - 6s 613ms/step - loss: 0.0680 - val_loss: 0.1768
# Epoch 6/100
# 10/10 [==============================] - 6s 636ms/step - loss: 0.0763 - val_loss: 0.4968
# Epoch 7/100
# 10/10 [==============================] - 6s 624ms/step - loss: 0.1279 - val_loss: 0.1540
# Epoch 8/100
# 10/10 [==============================] - 9s 977ms/step - loss: 0.0533 - val_loss: 0.1079
# Epoch 9/100
# 10/10 [==============================] - 8s 771ms/step - loss: 0.0627 - val_loss: 0.5443
# Epoch 10/100
# 10/10 [==============================] - 8s 779ms/step - loss: 0.1021 - val_loss: 0.3252
# Epoch 11/100
# 10/10 [==============================] - 9s 882ms/step - loss: 0.0851 - val_loss: 0.1235
# Epoch 12/100
# 10/10 [==============================] - 7s 742ms/step - loss: 0.0828 - val_loss: 0.3474
# Epoch 13/100
# 10/10 [==============================] - 7s 760ms/step - loss: 0.0789 - val_loss: 0.2016
# Epoch 14/100
# 10/10 [==============================] - 7s 733ms/step - loss: 0.0734 - val_loss: 0.1017
# Epoch 15/100
# 10/10 [==============================] - 7s 729ms/step - loss: 0.0518 - val_loss: 0.0633
# Epoch 16/100
# 10/10 [==============================] - 9s 897ms/step - loss: 0.0457 - val_loss: 0.2095
# Epoch 17/100
# 10/10 [==============================] - 8s 796ms/step - loss: 0.0522 - val_loss: 0.0997
# 10/10 [==============================] - 6s 613ms/step - loss: 0.0100 - val_loss: 0.0277
# Epoch 77/100
# 10/10 [==============================] - 6s 606ms/step - loss: 0.0102 - val_loss: 0.0190
# Epoch 78/100
# 10/10 [==============================] - 6s 624ms/step - loss: 0.0086 - val_loss: 0.0147
# Epoch 79/100
# 10/10 [==============================] - 6s 599ms/step - loss: 0.0104 - val_loss: 0.0473
# Epoch 80/100
# 10/10 [==============================] - 6s 603ms/step - loss: 0.0129 - val_loss: 0.0171
# Epoch 81/100
# 10/10 [==============================] - 7s 684ms/step - loss: 0.0071 - val_loss: 0.0143
# Epoch 82/100
# 10/10 [==============================] - 6s 616ms/step - loss: 0.0065 - val_loss: 0.0203
# Epoch 83/100
# 10/10 [==============================] - 6s 586ms/step - loss: 0.0084 - val_loss: 0.0252
# Epoch 84/100
# 10/10 [==============================] - 6s 574ms/step - loss: 0.0087 - val_loss: 0.0176
# Epoch 85/100
# 10/10 [==============================] - 6s 604ms/step - loss: 0.0037 - val_loss: 0.0138
# Epoch 86/100
# 10/10 [==============================] - 6s 582ms/step - loss: 0.0070 - val_loss: 0.0391
# Epoch 87/100
# 10/10 [==============================] - 5s 559ms/step - loss: 0.0100 - val_loss: 0.0136
# Epoch 88/100
# 10/10 [==============================] - 6s 589ms/step - loss: 0.0055 - val_loss: 0.0109
# Epoch 89/100
# 10/10 [==============================] - 5s 517ms/step - loss: 0.0055 - val_loss: 0.0225
# Epoch 90/100
# 10/10 [==============================] - 5s 481ms/step - loss: 0.0084 - val_loss: 0.0203
# Epoch 91/100
# 10/10 [==============================] - 5s 471ms/step - loss: 0.0088 - val_loss: 0.0241
# Epoch 92/100
# 10/10 [==============================] - 5s 480ms/step - loss: 0.0041 - val_loss: 0.0123
# Epoch 93/100
# 10/10 [==============================] - 5s 466ms/step - loss: 0.0064 - val_loss: 0.0452
# Epoch 94/100
# 10/10 [==============================] - 5s 471ms/step - loss: 0.0108 - val_loss: 0.0208
# Epoch 95/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0077 - val_loss: 0.0143
# Epoch 96/100
# 10/10 [==============================] - 5s 471ms/step - loss: 0.0074 - val_loss: 0.0305
# Epoch 97/100
# 10/10 [==============================] - 5s 468ms/step - loss: 0.0083 - val_loss: 0.0308
# Epoch 98/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0101 - val_loss: 0.0138
# Epoch 99/100
# 10/10 [==============================] - 6s 649ms/step - loss: 0.0066 - val_loss: 0.0109
# Epoch 100/100
# 10/10 [==============================] - 6s 600ms/step - loss: 0.0077 - val_loss: 0.0241

# %%
[mse(model_gas_uni.predict(gas_uni_testX).flatten(), gas_uni_testY.flatten()),\
 mse(model_gas_mult.predict(gas_mult_testX).flatten(), gas_mult_testY.flatten()),\
 mse(model_water_uni.predict(water_uni_testX).flatten(), water_uni_testY.flatten()),\
 mse(model_water_mult.predict(water_mult_testX).flatten(), water_mult_testY.flatten()),
 mse(model_oil_uni.predict(oil_uni_testX).flatten(), oil_uni_testY.flatten()),\
 mse(model_oil_mult.predict(oil_mult_testX).flatten(), oil_mult_testY.flatten())]
# Out:
# [0.003837826,
#  0.013499658,
#  0.0059103305,
#  0.0054071313,
#  0.0021244378,
#  0.00453796]

# %%
# summarize history for loss
plt.plot(history_oil_uni.history['loss'])
plt.plot(history_oil_uni.history['val_loss'])
plt.title('model loss for oil (UNI)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history_oil_mult.history['loss'])
plt.plot(history_oil_mult.history['val_loss'])
plt.title('model loss for oil (MULT)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## water
plt.plot(history_water_uni.history['loss'])
plt.plot(history_water_uni.history['val_loss'])
plt.title('model loss for water (UNI)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history_water_mult.history['loss'])
plt.plot(history_water_mult.history['val_loss'])
plt.title('model loss for water (MULT)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history_water_uni.history['loss'])
plt.plot(history_water_uni.history['val_loss'])
plt.title('model loss for water (UNI)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history_water_mult.history['loss'])
plt.plot(history_water_mult.history['val_loss'])
plt.title('model loss for water (MULT)(pressure)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
## Gas
plt.plot(history_gas_uni.history['loss'])
plt.plot(history_gas_uni.history['val_loss'])
plt.title('model loss for gas (UNI)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history_gas_mult.history['loss'])
plt.plot(history_gas_mult.history['val_loss'])
plt.title('model loss for gas (MULT)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
[mse(model_gas_uni.predict(gas_uni_testX).flatten(), gas_uni_testY.flatten()),\
 mse(model_gas_mult.predict(gas_mult_testX).flatten(), gas_mult_testY.flatten()),\
 mse(model_water_uni.predict(water_uni_testX).flatten(), water_uni_testY.flatten()),\
 mse(model_water_mult.predict(water_mult_testX).flatten(), water_mult_testY.flatten()),
 mse(model_oil_uni.predict(oil_uni_testX).flatten(), oil_uni_testY.flatten()),\
 mse(model_oil_mult.predict(oil_mult_testX).flatten(), oil_mult_testY.flatten())]

# %%
## gas testing data set visualization
# ### univariate 
# real_gas_uni = gas_uni_testY.flatten()
# pred_gas_uni = model_gas_uni.predict(gas_uni_testX).flatten()
# df_plot_gas_uni=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_gas_uni, real_gas_uni]))))
# df_plot_gas_uni['ds']=range(0,len(real_gas_uni))
# ### multivariate 
# real_gas_mult = gas_mult_testY.flatten()
# pred_gas_mult = model_gas_mult.predict(gas_mult_testX).flatten()
# df_plot_gas_mult=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_gas_mult, real_gas_mult]))))
# df_plot_gas_mult['ds']=range(0,len(real_gas_mult))
# ## water 
## univariate
real_water_uni = water_uni_testY.flatten()
pred_water_uni = model_water_uni.predict(water_uni_testX).flatten()
df_plot_water_uni=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([ pred_water_uni, real_water_uni]))))
df_plot_water_uni['ds']=range(0,len(real_water_uni))
## multivariate 
real_water_mult = water_mult_testY.flatten()
pred_water_mult = model_water_mult.predict(water_mult_testX).flatten()
df_plot_water_mult=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([ pred_water_mult, real_water_mult]))))
df_plot_water_mult['ds']=range(0,len(real_water_mult))
# ## oil
# ## univariate
# real_oil_uni = oil_uni_testY.flatten()
# pred_oil_uni = model_oil_uni.predict(oil_uni_testX).flatten()
# df_plot_oil_uni=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_oil_uni, real_oil_uni]))))
# df_plot_oil_uni['ds']=range(0,len(real_oil_uni))
# ## multivariate 
# real_oil_mult = oil_mult_testY.flatten()
# pred_oil_mult = model_oil_mult.predict(oil_mult_testX).flatten()
# df_plot_oil_mult=pd.DataFrame.from_dict(dict(zip(['prediction', 'real' ], np.array([pred_oil_mult, real_oil_mult]))))
# df_plot_oil_mult['ds']=range(0,len(real_oil_mult))

# %%
### GAS
start = 0
end = 1000
fig,ax = plt.subplots()
ax.set_title('(GAS) prediction vs real (Uni)')
ax.plot(df_plot_gas_uni['ds'].iloc[start:end], df_plot_gas_uni['prediction'].iloc[start:end], marker=".", label='prediction_gas')
ax.plot(df_plot_gas_uni['ds'].iloc[start:end], df_plot_gas_uni['real'].iloc[start:end], marker=".", label='real_gas')
ax.legend()
fig,ax = plt.subplots()
ax.set_title('(GAS) prediction vs real (Multi)')
ax.plot(df_plot_gas_mult['ds'].iloc[start:end], df_plot_gas_mult['prediction'].iloc[start:end], marker=".", label='prediction_gas')
ax.plot(df_plot_gas_mult['ds'].iloc[start:end], df_plot_gas_mult['real'].iloc[start:end], marker=".", label='real_gas')
ax.legend()

# %%
### WATER 
start = 0
end = 1000
fig,ax = plt.subplots()
ax.set_title('(WATER) prediction vs real (Uni)')
ax.plot(df_plot_water_uni['ds'].iloc[start:end], df_plot_water_uni['prediction'].iloc[start:end], marker=".", label='prediction_water')
ax.plot(df_plot_water_uni['ds'].iloc[start:end], df_plot_water_uni['real'].iloc[start:end], marker=".", label='real_water')
ax.legend()
fig,ax = plt.subplots()
ax.set_title('(WATER) prediction vs real (Multi)')
ax.plot(df_plot_water_mult['ds'].iloc[start:end], df_plot_water_mult['prediction'].iloc[start:end], marker=".", label='prediction_water')
ax.plot(df_plot_water_mult['ds'].iloc[start:end], df_plot_water_mult['real'].iloc[start:end], marker=".", label='real_water')
ax.legend()

# %%
fig,ax = plt.subplots()
ax.set_title('(WATER) prediction vs real (Multi) (pressure)')
ax.plot(df_plot_water_mult['ds'].iloc[start:end], df_plot_water_mult['prediction'].iloc[start:end], marker=".", label='prediction_water')
ax.plot(df_plot_water_mult['ds'].iloc[start:end], df_plot_water_mult['real'].iloc[start:end], marker=".", label='real_water')
ax.legend()

# %%
## OIL
start = 0
end = 1000
fig,ax = plt.subplots()
ax.set_title('(OIL) prediction vs real (Uni)')
ax.plot(df_plot_oil_uni['ds'].iloc[start:end], df_plot_oil_uni['prediction'].iloc[start:end], marker=".", label='prediction_oil')
ax.plot(df_plot_oil_uni['ds'].iloc[start:end], df_plot_oil_uni['real'].iloc[start:end], marker=".", label='real_oil')
ax.legend()
fig,ax = plt.subplots()
ax.set_title('(OIL) prediction vs real (Multi)')
ax.plot(df_plot_oil_mult['ds'].iloc[start:end], df_plot_oil_mult['prediction'].iloc[start:end], marker=".", label='prediction_oil')
ax.plot(df_plot_oil_mult['ds'].iloc[start:end], df_plot_oil_mult['real'].iloc[start:end], marker=".", label='real_oil')
ax.legend()
